# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
data = pd.read_csv('2023-2024-Horana-cleaned.csv') 

data['DATE'] = pd.to_datetime(data['DATE'])

data['NetAmount'] = data['NetAmount'].abs()

data['SalesPersonCode']
data.head()
# Out:
#         DATE      Time SalesPersonCode  NetAmount
# 0 2023-01-01   9:22 AM             265      490.0
# 1 2023-01-01   9:43 AM             430     1290.0
# 2 2023-01-01   9:45 AM             544     3790.0
# 3 2023-01-01  10:09 AM             265     3975.0
# 4 2023-01-01  10:16 AM             525     2290.0

# %%
last_year = data['DATE'].dt.year.max()

last_year_data = data[data['DATE'].dt.year == last_year]

valid_sales_persons = last_year_data['SalesPersonCode'].unique()

filtered_data = data[data['SalesPersonCode'].isin(valid_sales_persons)]

filtered_data.to_csv('filtered_Horana_cleaned.csv', index=False)

filtered_data.head()
# Out:
#         DATE      Time SalesPersonCode  NetAmount
# 0 2023-01-01   9:22 AM             265      490.0
# 1 2023-01-01   9:43 AM             430     1290.0
# 3 2023-01-01  10:09 AM             265     3975.0
# 6 2023-01-01  10:19 AM             430     1490.0
# 7 2023-01-01  10:21 AM             254     4590.0

# %%
# !pip install tensorflow
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import shap
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.11.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from tensorflow) (2.0.0)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=2.0 (from tensorflow)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast<=0.4.0,>=0.2.1 (from tensorflow)
#   Downloading gast-0.4.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.62.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting h5py>=2.9.0 (from tensorflow)
#   Using cached h5py-3.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting keras<2.12,>=2.11.0 (from tensorflow)
#   Downloading keras-2.11.0-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.20 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.21.6)
# Collecting opt-einsum>=2.3.2 (from tensorflow)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging in /home/pasiya/anaconda3/lib/python3.7/site-packages (from tensorflow) (24.0)
# Collecting protobuf<3.20,>=3.9.2 (from tensorflow)
#   Downloading protobuf-3.19.6-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (787 bytes)
# Requirement already satisfied: setuptools in /home/pasiya/anaconda3/lib/python3.7/site-packages (from tensorflow) (40.2.0)
# Requirement already satisfied: six>=1.12.0 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.16.0)
# Collecting tensorboard<2.12,>=2.11 (from tensorflow)
#   Downloading tensorboard-2.11.2-py3-none-any.whl.metadata (1.9 kB)
# Collecting tensorflow-estimator<2.12,>=2.11.0 (from tensorflow)
#   Downloading tensorflow_estimator-2.11.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Using cached termcolor-2.3.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from tensorflow) (4.7.1)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Using cached wrapt-1.16.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow)
#   Using cached tensorflow_io_gcs_filesystem-0.34.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from astunparse>=1.6.0->tensorflow) (0.31.1)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.12,>=2.11->tensorflow)
#   Downloading google_auth-2.38.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.12,>=2.11->tensorflow)
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.12,>=2.11->tensorflow)
#   Using cached Markdown-3.4.4-py3-none-any.whl.metadata (6.9 kB)
# Collecting requests<3,>=2.21.0 (from tensorboard<2.12,>=2.11->tensorflow)
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting setuptools (from tensorflow)
#   Using cached setuptools-68.0.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.12,>=2.11->tensorflow)
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl.metadata (1.1 kB)
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.12,>=2.11->tensorflow)
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl.metadata (873 bytes)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.12,>=2.11->tensorflow)
#   Using cached Werkzeug-2.2.3-py3-none-any.whl.metadata (4.4 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.2.2)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (4.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2018.8.24)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow)
#   Using cached MarkupSafe-2.1.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: zipp>=0.5 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.1 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.4.4)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Using cached tensorflow-2.11.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (588.3 MB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading grpcio-1.62.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 1.1 MB/s eta 0:00:00m eta 0:00:010:00:010m
# Using cached h5py-3.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
# Using cached keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 2.1 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Using cached protobuf-3.19.6-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Using cached tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
# Using cached setuptools-68.0.0-py3-none-any.whl (804 kB)
# Using cached tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
# Downloading tensorflow_io_gcs_filesystem-0.34.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 3.4 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Using cached termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Using cached wrapt-1.16.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
# Downloading google_auth-2.38.0-py2.py3-none-any.whl (210 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.8/210.8 kB 3.6 MB/s eta 0:00:00 MB/s eta 0:00:01
# Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Using cached Markdown-3.4.4-py3-none-any.whl (94 kB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 1.9 MB/s eta 0:00:000:00:01m eta 0:00:01
# Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Using cached Werkzeug-2.2.3-py3-none-any.whl (233 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Using cached MarkupSafe-2.1.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Installing collected packages: tensorboard-plugin-wit, libclang, flatbuffers, wrapt, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, setuptools, rsa, requests, protobuf, opt-einsum, oauthlib, MarkupSafe, keras, h5py, grpcio, google-pasta, gast, cachetools, astunparse, werkzeug, requests-oauthlib, markdown, google-auth, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.10.11
# ERROR: Cannot uninstall 'wrapt'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-5415f8013742> in <module>()
#       1 get_ipython().system('pip install tensorflow')
#       2 from sklearn.preprocessing import MinMaxScaler
# ----> 3 from tensorflow.keras.models import Sequential
#       4 from tensorflow.keras.layers import LSTM, Dense
#       5 import shap
#
# ModuleNotFoundError: No module named 'tensorflow'
