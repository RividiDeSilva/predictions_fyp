# %%
import pandas as pd
import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
from datetime import datetime

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/pasiya/anaconda3/lib/python3.7/site-packages (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from pandas) (2.7.3)
# Requirement already satisfied: pytz>=2017.2 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.15.4 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from pandas) (1.21.6)
# Requirement already satisfied: six>=1.5 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)

# %%
data = pd.read_csv('2023-2024-Horana-cleaned.csv') 

data['DATE'] = pd.to_datetime(data['DATE'])

data['NetAmount'] = data['NetAmount'].abs()

data['SalesPersonCode']
data.head()
# Out:
#         DATE      Time SalesPersonCode  NetAmount
# 0 2023-01-01   9:22 AM             265      490.0
# 1 2023-01-01   9:43 AM             430     1290.0
# 2 2023-01-01   9:45 AM             544     3790.0
# 3 2023-01-01  10:09 AM             265     3975.0
# 4 2023-01-01  10:16 AM             525     2290.0

# %%
last_year = data['DATE'].dt.year.max()

# Filter the data to include only the last year
last_year_data = data[data['DATE'].dt.year == last_year]

valid_sales_persons = last_year_data['SalesPersonCode'].unique()

filtered_data = data[data['SalesPersonCode'].isin(valid_sales_persons)]

filtered_data.to_csv('filtered_Horana_cleaned.csv', index=False)

filtered_data.head()
# Out:
#         DATE      Time SalesPersonCode  NetAmount
# 0 2023-01-01   9:22 AM             265      490.0
# 1 2023-01-01   9:43 AM             430     1290.0
# 3 2023-01-01  10:09 AM             265     3975.0
# 6 2023-01-01  10:19 AM             430     1490.0
# 7 2023-01-01  10:21 AM             254     4590.0

# %%
# !pip uninstall tensorflow
# !pip install tensorflow==2.4.0
# Out:
# WARNING: Skipping tensorflow as it is not installed.
# Collecting tensorflow==2.4.0
#   Using cached tensorflow-2.4.0-cp37-cp37m-manylinux2010_x86_64.whl.metadata (2.7 kB)
# Collecting absl-py~=0.10 (from tensorflow==2.4.0)
#   Using cached absl_py-0.15.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting astunparse~=1.6.3 (from tensorflow==2.4.0)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers~=1.12.0 (from tensorflow==2.4.0)
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl.metadata (872 bytes)
# Collecting google-pasta~=0.2 (from tensorflow==2.4.0)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py~=2.10.0 (from tensorflow==2.4.0)
#   Using cached h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl.metadata (2.0 kB)
# Collecting keras-preprocessing~=1.1.2 (from tensorflow==2.4.0)
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting numpy~=1.19.2 (from tensorflow==2.4.0)
#   Using cached numpy-1.19.5-cp37-cp37m-manylinux2010_x86_64.whl.metadata (2.0 kB)
# Collecting opt-einsum~=3.3.0 (from tensorflow==2.4.0)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting protobuf>=3.9.2 (from tensorflow==2.4.0)
#   Using cached protobuf-4.24.4-cp37-abi3-manylinux2014_x86_64.whl.metadata (540 bytes)
# Collecting six~=1.15.0 (from tensorflow==2.4.0)
#   Using cached six-1.15.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting termcolor~=1.1.0 (from tensorflow==2.4.0)
#   Using cached termcolor-1.1.0-py3-none-any.whl
# Collecting typing-extensions~=3.7.4 (from tensorflow==2.4.0)
#   Using cached typing_extensions-3.7.4.3-py3-none-any.whl.metadata (2.0 kB)
# Collecting wheel~=0.35 (from tensorflow==2.4.0)
#   Using cached wheel-0.42.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting wrapt~=1.12.1 (from tensorflow==2.4.0)
#   Using cached wrapt-1.12.1-cp37-cp37m-linux_x86_64.whl
# Collecting gast==0.3.3 (from tensorflow==2.4.0)
#   Using cached gast-0.3.3-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting tensorboard~=2.4 (from tensorflow==2.4.0)
#   Using cached tensorboard-2.11.2-py3-none-any.whl.metadata (1.9 kB)
# Collecting tensorflow-estimator<2.5.0,>=2.4.0rc0 (from tensorflow==2.4.0)
#   Using cached tensorflow_estimator-2.4.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting grpcio~=1.32.0 (from tensorflow==2.4.0)
#   Using cached grpcio-1.32.0-cp37-cp37m-manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard~=2.4->tensorflow==2.4.0)
#   Using cached google_auth-2.38.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard~=2.4->tensorflow==2.4.0)
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard~=2.4->tensorflow==2.4.0)
#   Using cached Markdown-3.4.4-py3-none-any.whl.metadata (6.9 kB)
# Collecting protobuf>=3.9.2 (from tensorflow==2.4.0)
#   Using cached protobuf-3.20.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (679 bytes)
# Collecting requests<3,>=2.21.0 (from tensorboard~=2.4->tensorflow==2.4.0)
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting setuptools>=41.0.0 (from tensorboard~=2.4->tensorflow==2.4.0)
#   Using cached setuptools-68.0.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard~=2.4->tensorflow==2.4.0)
#   Using cached tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from tensorboard~=2.4->tensorflow==2.4.0) (1.8.1)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.4->tensorflow==2.4.0)
#   Using cached Werkzeug-2.2.3-py3-none-any.whl.metadata (4.4 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0)
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0) (0.2.2)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow==2.4.0)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.0) (4.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0) (2018.8.24)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard~=2.4->tensorflow==2.4.0)
#   Using cached MarkupSafe-2.1.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: zipp>=0.5 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.0) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.1 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0) (0.4.4)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow==2.4.0)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Using cached tensorflow-2.4.0-cp37-cp37m-manylinux2010_x86_64.whl (394.7 MB)
# Using cached gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Using cached absl_py-0.15.0-py3-none-any.whl (132 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Using cached grpcio-1.32.0-cp37-cp37m-manylinux2014_x86_64.whl (3.8 MB)
# Using cached h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
# Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Using cached numpy-1.19.5-cp37-cp37m-manylinux2010_x86_64.whl (14.8 MB)
# Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# Using cached tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
# Using cached protobuf-3.20.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# Using cached tensorflow_estimator-2.4.0-py2.py3-none-any.whl (462 kB)
# Using cached typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Using cached wheel-0.42.0-py3-none-any.whl (65 kB)
# Using cached google_auth-2.38.0-py2.py3-none-any.whl (210 kB)
# Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Using cached Markdown-3.4.4-py3-none-any.whl (94 kB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached setuptools-68.0.0-py3-none-any.whl (804 kB)
# Using cached tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
# Using cached Werkzeug-2.2.3-py3-none-any.whl (233 kB)
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Using cached MarkupSafe-2.1.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Installing collected packages: wrapt, typing-extensions, termcolor, tensorflow-estimator, flatbuffers, wheel, tensorboard-data-server, six, setuptools, rsa, requests, protobuf, oauthlib, numpy, MarkupSafe, gast, cachetools, werkzeug, requests-oauthlib, opt-einsum, markdown, keras-preprocessing, h5py, grpcio, google-pasta, google-auth, astunparse, absl-py, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.10.11
# ERROR: Cannot uninstall 'wrapt'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.18.0

# %%
# !pip install shap
# Out:
# Collecting shap
#   Using cached shap-0.42.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (23 kB)
# Requirement already satisfied: numpy in /home/pasiya/anaconda3/lib/python3.7/site-packages (from shap) (1.21.6)
# Requirement already satisfied: scipy in /home/pasiya/anaconda3/lib/python3.7/site-packages (from shap) (1.7.3)
# Requirement already satisfied: scikit-learn in /home/pasiya/anaconda3/lib/python3.7/site-packages (from shap) (1.0.2)
# Requirement already satisfied: pandas in /home/pasiya/anaconda3/lib/python3.7/site-packages (from shap) (1.1.5)
# Requirement already satisfied: tqdm>=4.27.0 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from shap) (24.0)
# Collecting slicer==0.0.7 (from shap)
#   Using cached slicer-0.0.7-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: numba in /home/pasiya/anaconda3/lib/python3.7/site-packages (from shap) (0.39.0)
# Requirement already satisfied: cloudpickle in /home/pasiya/anaconda3/lib/python3.7/site-packages (from shap) (0.5.5)
# Requirement already satisfied: llvmlite>=0.24.0dev0 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from numba->shap) (0.24.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from pandas->shap) (2.7.3)
# Requirement already satisfied: pytz>=2017.2 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from pandas->shap) (2023.3)
# Requirement already satisfied: joblib>=0.11 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from scikit-learn->shap) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from scikit-learn->shap) (3.1.0)
# Requirement already satisfied: six>=1.5 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->shap) (1.16.0)
# Using cached shap-0.42.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (545 kB)
# Using cached slicer-0.0.7-py3-none-any.whl (14 kB)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.42.1 slicer-0.0.7

# %%
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import shap

# %%
# import numpy as np
# def dummy_npwarn_decorator_factory():
#   def npwarn_decorator(x):
#     return x
#   return npwarn_decorator
# np._no_nep50_warning = getattr(np, '_no_nep50_warning', dummy_npwarn_decorator_factory)

# %%
# from sklearn.preprocessing import MinMaxScaler
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import LSTM, Dense
# import shap

# %%
# !pip install numpy 2.0.4?
# Out:
# Requirement already satisfied: numpy in ./lstm/lib/python3.10/site-packages (1.26.4)
# ERROR: Could not find a version that satisfies the requirement 2.0.4 (from versions: none)
# ERROR: No matching distribution found for 2.0.4

# %%
# !pip install numpy==2.?1
# Out:
# Collecting numpy==2.1
#   Using cached numpy-2.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.1.0 which is incompatible.
# langchain 0.3.19 requires numpy<2,>=1.26.4; python_version < "3.12", but you have numpy 2.1.0 which is incompatible.
# Successfully installed numpy-2.1.0

# %%
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %%
# !pip install shap
# import shap
# Out:
# Requirement already satisfied: shap in ./lstm/lib/python3.10/site-packages (0.46.0)
# Requirement already satisfied: packaging>20.9 in ./lstm/lib/python3.10/site-packages (from shap) (24.2)
# Requirement already satisfied: scipy in ./lstm/lib/python3.10/site-packages (from shap) (1.15.2)
# Requirement already satisfied: cloudpickle in ./lstm/lib/python3.10/site-packages (from shap) (3.1.1)
# Requirement already satisfied: numba in ./lstm/lib/python3.10/site-packages (from shap) (0.61.0)
# Requirement already satisfied: scikit-learn in ./lstm/lib/python3.10/site-packages (from shap) (1.6.1)
# Requirement already satisfied: slicer==0.0.8 in ./lstm/lib/python3.10/site-packages (from shap) (0.0.8)
# Requirement already satisfied: pandas in ./lstm/lib/python3.10/site-packages (from shap) (2.2.3)
# Requirement already satisfied: tqdm>=4.27.0 in ./lstm/lib/python3.10/site-packages (from shap) (4.67.1)
# Requirement already satisfied: numpy in ./lstm/lib/python3.10/site-packages (from shap) (2.1.0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in ./lstm/lib/python3.10/site-packages (from numba->shap) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in ./lstm/lib/python3.10/site-packages (from pandas->shap) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in ./lstm/lib/python3.10/site-packages (from pandas->shap) (2025.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./lstm/lib/python3.10/site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.2.0 in ./lstm/lib/python3.10/site-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./lstm/lib/python3.10/site-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: six>=1.5 in ./lstm/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[20], line 2
#       1 get_ipython().system('pip install shap')
# ----> 2 import shap
#
# File ~/sales_forcast/jupytercode/lstm/lib/python3.10/site-packages/shap/__init__.py:1
# ----> 1 from ._explanation import Cohorts, Explanation
#       3 # explainers
#       4 from .explainers import other
#
# File ~/sales_forcast/jupytercode/lstm/lib/python3.10/site-packages/shap/_explanation.py:13
#      10 import sklearn
#      11 from slicer import Alias, Obj, Slicer
# ---> 13 from .utils._exceptions import DimensionError
#      14 from .utils._general import OpChain
#      16 op_chain_root = OpChain("shap.Explanation")
#
# File ~/sales_forcast/jupytercode/lstm/lib/python3.10/site-packages/shap/utils/__init__.py:1
# ----> 1 from ._clustering import (
#       2     delta_minimization_order,
#       3     hclust,
#       4     hclust_ordering,
#       5     partition_tree,
#       6     partition_tree_shuffle,
#       7 )
#       8 from ._general import (
#       9     OpChain,
#      10     approximate_interactions,
#    (...)
#      20     suppress_stderr,
#      21 )
#      22 from ._masked_model import MaskedModel, make_masks
#
# File ~/sales_forcast/jupytercode/lstm/lib/python3.10/site-packages/shap/utils/_clustering.py:8
#       6 import scipy.spatial
#       7 import sklearn
# ----> 8 from numba import njit
#      10 from ._show_progress import show_progress
#      13 def partition_tree(X, metric="correlation"):
#
# File ~/sales_forcast/jupytercode/lstm/lib/python3.10/site-packages/numba/__init__.py:59
#      54             msg = ("Numba requires SciPy version 1.0 or greater. Got SciPy "
#      55                    f"{scipy.__version__}.")
#      56             raise ImportError(msg)
# ---> 59 _ensure_critical_deps()
#      60 # END DO NOT MOVE
#      61 # ---------------------- WARNING WARNING WARNING ----------------------------
#      64 from ._version import get_versions
#
# File ~/sales_forcast/jupytercode/lstm/lib/python3.10/site-packages/numba/__init__.py:45, in _ensure_critical_deps()
#      42 if numpy_version > (2, 1):
#      43     msg = (f"Numba needs NumPy 2.1 or less. Got NumPy "
#      44            f"{numpy_version[0]}.{numpy_version[1]}.")
# ---> 45     raise ImportError(msg)
#      47 try:
#      48     import scipy
#
# ImportError: Numba needs NumPy 2.1 or less. Got NumPy 2.2.

# %%
data = pd.read_csv('filtered_Horana_cleaned.csv')

data['DATE'] = pd.to_datetime(data['DATE'])

daily_sales = data.groupby(['DATE', 'SalesPersonCode'])['NetAmount'].sum().reset_index()

pivot_data = daily_sales.pivot(index='DATE', columns='SalesPersonCode', values='NetAmount').fillna(0)

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(pivot_data)

def create_dataset(data, time_step=30):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step), :])
        y.append(data[i + time_step, :])
    return np.array(X), np.array(y)

time_step = 30  
X, y = create_dataset(scaled_data, time_step)

X = X.reshape(X.shape[0], X.shape[1], X.shape[2])

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(time_step, X.shape[2])))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(X.shape[2]))  # Output layer with one unit per SalesPersonCode

model.compile(optimizer='adam', loss='mean_squared_error')

model.fit(X, y, epochs=20, batch_size=32, verbose=1)
# Out:
# Epoch 1/20
# /home/pasiya/sales_forcast/jupytercode/lstm/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[48], line 8
#       4 model.add(Dense(X.shape[2]))  # Output layer with one unit per SalesPersonCode
#       6 model.compile(optimizer='adam', loss='mean_squared_error')
# ----> 8 model.fit(X, y, epochs=20, batch_size=32, verbose=1)
#
# File ~/sales_forcast/jupytercode/lstm/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/sales_forcast/jupytercode/lstm/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:77, in TensorFlowTrainer.train_step(self, data)
#      75 if self.trainable_weights:
#      76     trainable_weights = self.trainable_weights
# ---> 77     gradients = tape.gradient(loss, trainable_weights)
#      79     # Update weights
#      80     self.optimizer.apply_gradients(zip(gradients, trainable_weights))
#
# LookupError: gradient registry has no entry for: shap_DivNoNan

# %%
last_30_days = scaled_data[-time_step:]  
predictions = []

for _ in range(30):  
    last_30_days_reshaped = last_30_days.reshape(1, time_step, X.shape[2])
    next_day_pred = model.predict(last_30_days_reshaped)
    predictions.append(next_day_pred[0])
    last_30_days = np.vstack([last_30_days[1:], next_day_pred])

predictions = scaler.inverse_transform(predictions)

prediction_dates = pd.date_range(start=pivot_data.index[-1] + pd.Timedelta(days=1), periods=30)
prediction_df = pd.DataFrame(predictions, columns=pivot_data.columns, index=prediction_dates)

prediction_df.to_csv('upcoming_month_sales_predictions.csv')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
def predict_upcoming_month_sales(sales_person_code):
    last_30_days = scaled_data[-time_step:]  # Last 30 days of data
    predictions = []

    for _ in range(30): 
        last_30_days_reshaped = last_30_days.reshape(1, time_step, X.shape[2])
        next_day_pred = model.predict(last_30_days_reshaped)
        predictions.append(next_day_pred[0])
        last_30_days = np.vstack([last_30_days[1:], next_day_pred])

    predictions = scaler.inverse_transform(predictions)

    prediction_dates = pd.date_range(start=pivot_data.index[-1] + pd.Timedelta(days=1), periods=30)
    prediction_df = pd.DataFrame(predictions, columns=pivot_data.columns, index=prediction_dates)

    total_sales = prediction_df[sales_person_code].sum()
    return total_sales

# %%
sales_person_code = '265'
total_predicted_sales = predict_upcoming_month_sales(sales_person_code)
print(f"Total predicted sales for SalesPersonCode {sales_person_code} in the upcoming month: {total_predicted_sales:.2f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Total predicted sales for SalesPersonCode 265 in the upcoming month: 4574943.91

# %%
train_size = int(len(scaled_data) * 0.8)
train_data, test_data = scaled_data[:train_size], scaled_data[train_size - time_step:]

# %%
X_test, y_test = create_dataset(test_data, time_step)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2])

# %%
y_pred_scaled = model.predict(X_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
y_pred = scaler.inverse_transform(y_pred_scaled)
y_test_original = scaler.inverse_transform(y_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

mse = mean_squared_error(y_test_original, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_original, y_pred)

print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
# Mean Squared Error (MSE): 327890580.16
# Root Mean Squared Error (RMSE): 18107.75
# Mean Absolute Error (MAE): 8460.30

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import adfuller

data = pd.read_csv('2023-2024-Horana-cleaned.csv')
data['DATE'] = pd.to_datetime(data['DATE'])
data['NetAmount'] = data['NetAmount'].abs()

sales_265 = data[data['SalesPersonCode'] == '0']

sales_265_monthly = sales_265.resample('M', on='DATE')['NetAmount'].sum().reset_index()

plt.figure(figsize=(12, 6))
plt.plot(sales_265_monthly['DATE'], sales_265_monthly['NetAmount'], marker='o', linestyle='-')
plt.title('Monthly Sales Trend for SalesPersonCode 254')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_4855/728557607.py:16: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   sales_265_monthly = sales_265.resample('M', on='DATE')['NetAmount'].sum().reset_index()

# %%
def adf_test(series):
    result = adfuller(series, autolag='AIC')
    print("ADF Test Results:")
    print(f"Test Statistic: {result[0]}")
    print(f"P-Value: {result[1]}")
    print(f"Critical Values: {result[4]}")
    if result[1] <= 0.05:
        print("Data is stationary (reject H0)")
    else:
        print("Data is non-stationary (fail to reject H0)")

adf_test(sales_265_monthly['NetAmount'])
# Out:
# ADF Test Results:
# Test Statistic: -3.8415316739618284
# P-Value: 0.0025098579085580087
# Critical Values: {'1%': np.float64(-3.7529275211638033), '5%': np.float64(-2.998499866852963), '10%': np.float64(-2.6389669754253307)}
# Data is stationary (reject H0)

# %%
sales_265_monthly['Rolling_Mean'] = sales_265_monthly['NetAmount'].rolling(window=3).mean()
sales_265_monthly['Rolling_Std'] = sales_265_monthly['NetAmount'].rolling(window=3).std()

plt.figure(figsize=(12, 6))
plt.plot(sales_265_monthly['DATE'], sales_265_monthly['NetAmount'], label='Original Sales', color='blue')
plt.plot(sales_265_monthly['DATE'], sales_265_monthly['Rolling_Mean'], label='Rolling Mean', color='red')
plt.plot(sales_265_monthly['DATE'], sales_265_monthly['Rolling_Std'], label='Rolling Std Dev', color='green')
plt.title('Rolling Mean & Standard Deviation for SalesPersonCode 254')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.legend()
plt.grid(True)
plt.show()

# %%
sales_265_monthly['Diff_1'] = sales_265_monthly['NetAmount'].diff().dropna()

print("\nADF Test after First Differencing:")
adf_test(sales_265_monthly['Diff_1'].dropna())

plt.figure(figsize=(12, 6))
plt.plot(sales_265_monthly['DATE'], sales_265_monthly['Diff_1'], marker='o', linestyle='-')
plt.title('Differenced Monthly Sales for SalesPersonCode 265')
plt.xlabel('Date')
plt.ylabel('Differenced Sales')
plt.grid(True)
plt.show()
# Out:
# ADF Test after First Differencing:
# ADF Test Results:
# Test Statistic: -6.18355426564665
# P-Value: 6.369144871750838e-08
# Critical Values: {'1%': np.float64(-3.769732625845229), '5%': np.float64(-3.005425537190083), '10%': np.float64(-2.6425009917355373)}
# Data is stationary (reject H0)

# %%
pip install --upgrade shap tensorflow keras numpy
# Out:
# Requirement already satisfied: shap in ./lstm/lib/python3.10/site-packages (0.46.0)
# Requirement already satisfied: tensorflow in ./lstm/lib/python3.10/site-packages (2.18.0)

# %%
# !pip install seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

data = pd.read_csv('2023-2024-Horana-cleaned.csv')
data['DATE'] = pd.to_datetime(data['DATE'])
data['NetAmount'] = data['NetAmount'].abs()  # Ensure all values are positive

sales_265 = data[data['SalesPersonCode'] == '265']

sales_265_monthly = sales_265.resample('M', on='DATE')['NetAmount'].sum().reset_index()
sales_265_monthly.set_index('DATE', inplace=True)

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_sales = scaler.fit_transform(sales_265_monthly[['NetAmount']])

sales_265_monthly['NetAmount_Diff'] = sales_265_monthly['NetAmount'].diff().dropna()
sales_265_monthly.dropna(inplace=True)

scaler_diff = MinMaxScaler(feature_range=(-1, 1))
scaled_diff_data = scaler_diff.fit_transform(sales_265_monthly[['NetAmount_Diff']])

def create_dataset(data, time_step=12):
    X, y = [], []
    for i in range(len(data) - time_step):
        X.append(data[i:i + time_step, 0])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)

time_step = 12  
X, y = create_dataset(scaled_diff_data, time_step)

X = X.reshape(X.shape[0], X.shape[1], 1)

train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(time_step, 1)),
    LSTM(50, return_sequences=False),
    Dense(1)
])

model.compile(optimizer='adam', loss='mean_squared_error')

model.fit(X_train, y_train, epochs=50, batch_size=8, verbose=1)

last_12_months = scaled_diff_data[-time_step:].reshape(1, time_step, 1)
predicted_scaled_diff = model.predict(last_12_months)

predicted_diff_value = scaler_diff.inverse_transform([[predicted_scaled_diff[0][0]]])[0][0]
previous_month_sales = sales_265_monthly['NetAmount'].iloc[-1]
predicted_sales = previous_month_sales + predicted_diff_value  # Reverse differencing

actual_sales = sales_265_monthly['NetAmount'].iloc[-1]

print(f"Actual Sales for Last Month: {actual_sales:.2f}")
print(f"Predicted Sales for Last Month: {predicted_sales:.2f}")

plt.figure(figsize=(10, 5))
plt.plot(sales_265_monthly.index[-12:], sales_265_monthly['NetAmount'][-12:], label="Actual", marker='o')
plt.axhline(y=predicted_sales, color='r', linestyle='--', label="Predicted Last Month")
plt.legend()
plt.title("Actual vs Predicted Monthly Sales for SalesPerson 254")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.grid()
plt.show()
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 KB 1.8 MB/s eta 0:00:001.9 MB/s eta 0:00:01
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in ./tf/lib/python3.10/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in ./tf/lib/python3.10/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in ./tf/lib/python3.10/site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./tf/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: cycler>=0.10 in ./tf/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./tf/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: packaging>=20.0 in ./tf/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in ./tf/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./tf/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./tf/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./tf/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: tzdata>=2022.7 in ./tf/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: pytz>=2020.1 in ./tf/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in ./tf/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# 2025-03-20 11:26:03.145364: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-20 11:26:03.166127: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-20 11:26:03.181293: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-20 11:26:03.181320: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-20 11:26:03.190312: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-20 11:26:03.738925: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /tmp/ipykernel_10801/304908715.py:20: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   sales_265_monthly = sales_265.resample('M', on='DATE')['NetAmount'].sum().reset_index()
# 2025-03-20 11:26:04.226988: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:282] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# /home/pasiya/sales_forcast/jupytercode/tf/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0945
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0898
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0860
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0828
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0805
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0791
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0788
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0791
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0794
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0792
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0782
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0768
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0753
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0739
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0726
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0714
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0703
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0690
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0676
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0658
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0638
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0615
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0592
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0573
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0560
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0552
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0547
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0547
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0554
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0560
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0555
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0542
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0526
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0515
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0507
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0503
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0500
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0497
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0495
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0491
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0486
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0479
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0470
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0460
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0450
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0442
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0436
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0431
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0427
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0421
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Actual Sales for Last Month: 3760003.98
# Predicted Sales for Last Month: 3050598.11

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

data = pd.read_csv('2023-2024-Horana-cleaned.csv')
data['DATE'] = pd.to_datetime(data['DATE'])
data['NetAmount'] = data['NetAmount'].abs()  # Ensure all values are positive

sales_265 = data[data['SalesPersonCode'] == '265']

sales_265_monthly = sales_265.resample('M', on='DATE')['NetAmount'].sum().reset_index()
sales_265_monthly.set_index('DATE', inplace=True)

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_sales = scaler.fit_transform(sales_265_monthly[['NetAmount']])

def create_dataset(data, time_step=12):
    X, y = [], []
    for i in range(len(data) - time_step):
        X.append(data[i:i + time_step, 0])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)

time_step = 12  
X, y = create_dataset(scaled_sales, time_step)

X = X.reshape(X.shape[0], X.shape[1], 1)

train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

print(X_test[0:5])
print(y_test[0:5])

model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(time_step, 1)),
    LSTM(50, return_sequences=False),
    Dense(1)
])

model.compile(optimizer='adam', loss='mean_squared_error')

model.fit(X_train, y_train, epochs=50, batch_size=8, verbose=1)

last_12_months = scaled_sales[-time_step:].reshape(1, time_step, 1)
predicted_scaled = model.predict(last_12_months)

predicted_sales = scaler.inverse_transform([[predicted_scaled[0][0]]])[0][0]

actual_sales = sales_265_monthly['NetAmount'].iloc[-1]

print(f"Actual Sales for Last Month: {actual_sales:.2f}")
print(f"Predicted Sales for Last Month: {predicted_sales:.2f}")

plt.figure(figsize=(10, 5))
plt.plot(sales_265_monthly.index[-12:], sales_265_monthly['NetAmount'][-12:], label="Actual", marker='o')
plt.axhline(y=predicted_sales, color='r', linestyle='--', label="Predicted Last Month")
plt.legend()
plt.title("Actual vs Predicted Monthly Sales for SalesPerson 254")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.grid()
plt.show()
# Out:
# [[[0.37299027]
#   [0.32504311]
#   [0.84524082]
#   [0.4380347 ]
#   [0.1994462 ]
#   [0.40915856]
#   [0.63738907]
#   [0.32098713]
#   [0.39686476]
#   [0.5424924 ]
#   [0.57958473]
#   [0.47801379]]
#
#  [[0.32504311]
#   [0.84524082]
#   [0.4380347 ]
#   [0.1994462 ]
#   [0.40915856]
#   [0.63738907]
#   [0.32098713]
#   [0.39686476]
#   [0.5424924 ]
#   [0.57958473]
#   [0.47801379]
#   [0.3257526 ]]
#
#  [[0.84524082]
#   [0.4380347 ]
#   [0.1994462 ]
#   [0.40915856]
#   [0.63738907]
#   [0.32098713]
#   [0.39686476]
#   [0.5424924 ]
#   [0.57958473]
#   [0.47801379]
#   [0.3257526 ]
#   [0.40509156]]]
# [0.3257526  0.40509156 1.        ]
# Epoch 1/50
# /tmp/ipykernel_10801/501620636.py:17: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   sales_265_monthly = sales_265.resample('M', on='DATE')['NetAmount'].sum().reset_index()
# /home/pasiya/sales_forcast/jupytercode/tf/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2164
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1526
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0948
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0469
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0205
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0172
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0379
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0397
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0199
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0154
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0162
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0186
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0235
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0228
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0204
# Epoch 16/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0167
# Epoch 17/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0145
# Epoch 18/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0143
# Epoch 19/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0145
# Epoch 20/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0160
# Epoch 21/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0143
# Epoch 22/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0165
# Epoch 23/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0143
# Epoch 24/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0147
# Epoch 25/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0148
# Epoch 26/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0148
# Epoch 27/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0149
# Epoch 28/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0146
# Epoch 29/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0130
# Epoch 30/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0145
# Epoch 31/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0135
# Epoch 32/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0155
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0130
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0149
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0152
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0157
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0151
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0124
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0122
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0147
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0191
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0197
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0193
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0153
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0164
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0127
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0149
# Epoch 48/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0172
# Epoch 49/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0180
# Epoch 50/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0171
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Actual Sales for Last Month: 3760003.98
# Predicted Sales for Last Month: 2098880.91

# %%
import shap
import numpy as np

print("SHAP Version:", shap.__version__)

try:
    explainer = shap.DeepExplainer(model, X_train)
    shap_values = explainer.shap_values(X_test)
except Exception as e:
    print("DeepExplainer failed, switching to KernelExplainer...")
    background_samples = min(X_train.shape[0], 50)  # Avoid selecting more than available
    background = X_train[np.random.choice(X_train.shape[0], background_samples, replace=False)]
    explainer = shap.KernelExplainer(model.predict, background)

    X_test_2d = X_test.reshape(X_test.shape[0], -1)  # Flatten timesteps and features into a single dimension
    shap_values = explainer.shap_values(X_test_2d[:10])  # Use a small test set

print("\n==== SHAP Debugging Info ====")
print("SHAP Values Type:", type(shap_values))
print("SHAP Values Shape:", np.array(shap_values).shape)
print("X_test Shape:", X_test.shape)

try:
    expected_value = explainer.expected_value
    print("Expected Value:", expected_value)
except AttributeError:
    print("Error: 'expected_value' not found in explainer.")
    expected_value = None

print("\nSample Check:")
print("SHAP Values First Sample:", shap_values[0])
print("X_test First Sample:", X_test[0])

if shap_values.shape == X_test_2d.shape:
    shap.initjs()
    shap.force_plot(expected_value, shap_values[0], X_test_2d[0], feature_names=["NetAmount"])
    shap.summary_plot(shap_values, X_test_2d, feature_names=["NetAmount"])
    shap.dependence_plot(0, shap_values, X_test_2d, feature_names=["NetAmount"])
else:
    print("\nERROR: Shapes still do not match. Debug needed.")
# Out:
# SHAP Version: 0.46.0
# DeepExplainer failed, switching to KernelExplainer...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#   0%|          | 0/3 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 20
#      18     # Reshape X_test to 2D before passing to KernelExplainer
#      19     X_test_2d = X_test.reshape(X_test.shape[0], -1)  # Flatten timesteps and features into a single dimension
# ---> 20     shap_values = explainer.shap_values(X_test_2d[:10])  # Use a small test set
#      22 # Debugging Prints
#      23 print("\n==== SHAP Debugging Info ====")
#
# File ~/sales_forcast/jupytercode/lstm/lib/python3.10/site-packages/shap/explainers/_kernel.py:271, in KernelExplainer.shap_values(self, X, **kwargs)
#     269 if self.keep_index:
#     270     data = convert_to_instance_with_index(data, column_name, index_value[i:i + 1], index_name)
# --> 271 explanations.append(self.explain(data, **kwargs))
#     272 if kwargs.get("gc_collect", False):
#     273     gc.collect()
#
# File ~/sales_forcast/jupytercode/lstm/lib/python3.10/site-packages/shap/explainers/_kernel.py:322, in KernelExplainer.explain(self, incoming_instance, **kwargs)
#     320     model_out = self.model.f(instance.convert_to_df())
#     321 else:
# --> 322     model_out = self.model.f(instance.x)
#     323 if isinstance(model_out, (pd.DataFrame, pd.Series)):
#     324     model_out = model_out.values
#
# File ~/sales_forcast/jupytercode/lstm/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/sales_forcast/jupytercode/lstm/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# ValueError: Exception encountered when calling Sequential.call().
#
# Cannot take the length of shape with unknown rank.
#
# Arguments received by Sequential.call():
#   • inputs=tf.Tensor(shape=<unknown>, dtype=float32)
#   • training=False
#   • mask=None

# %%
# !pip install tensorflow==2.4.0
# Out:
# Collecting tensorflow==2.4.0
#   Downloading tensorflow-2.4.0-cp37-cp37m-manylinux2010_x86_64.whl.metadata (2.7 kB)
# Collecting absl-py~=0.10 (from tensorflow==2.4.0)
#   Downloading absl_py-0.15.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting astunparse~=1.6.3 (from tensorflow==2.4.0)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers~=1.12.0 (from tensorflow==2.4.0)
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl.metadata (872 bytes)
# Collecting google-pasta~=0.2 (from tensorflow==2.4.0)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py~=2.10.0 (from tensorflow==2.4.0)
#   Using cached h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl.metadata (2.0 kB)
# Collecting keras-preprocessing~=1.1.2 (from tensorflow==2.4.0)
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting numpy~=1.19.2 (from tensorflow==2.4.0)
#   Downloading numpy-1.19.5-cp37-cp37m-manylinux2010_x86_64.whl.metadata (2.0 kB)
# Collecting opt-einsum~=3.3.0 (from tensorflow==2.4.0)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting protobuf>=3.9.2 (from tensorflow==2.4.0)
#   Using cached protobuf-4.24.4-cp37-abi3-manylinux2014_x86_64.whl.metadata (540 bytes)
# Collecting six~=1.15.0 (from tensorflow==2.4.0)
#   Downloading six-1.15.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting termcolor~=1.1.0 (from tensorflow==2.4.0)
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting typing-extensions~=3.7.4 (from tensorflow==2.4.0)
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl.metadata (2.0 kB)
# Collecting wheel~=0.35 (from tensorflow==2.4.0)
#   Using cached wheel-0.42.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting wrapt~=1.12.1 (from tensorflow==2.4.0)
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gast==0.3.3 (from tensorflow==2.4.0)
#   Using cached gast-0.3.3-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting tensorboard~=2.4 (from tensorflow==2.4.0)
#   Using cached tensorboard-2.11.2-py3-none-any.whl.metadata (1.9 kB)
# Collecting tensorflow-estimator<2.5.0,>=2.4.0rc0 (from tensorflow==2.4.0)
#   Downloading tensorflow_estimator-2.4.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting grpcio~=1.32.0 (from tensorflow==2.4.0)
#   Downloading grpcio-1.32.0-cp37-cp37m-manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard~=2.4->tensorflow==2.4.0)
#   Using cached google_auth-2.38.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard~=2.4->tensorflow==2.4.0)
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard~=2.4->tensorflow==2.4.0)
#   Using cached Markdown-3.4.4-py3-none-any.whl.metadata (6.9 kB)
# Collecting protobuf>=3.9.2 (from tensorflow==2.4.0)
#   Downloading protobuf-3.20.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (679 bytes)
# Collecting requests<3,>=2.21.0 (from tensorboard~=2.4->tensorflow==2.4.0)
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting setuptools>=41.0.0 (from tensorboard~=2.4->tensorflow==2.4.0)
#   Using cached setuptools-68.0.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard~=2.4->tensorflow==2.4.0)
#   Using cached tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from tensorboard~=2.4->tensorflow==2.4.0) (1.8.1)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.4->tensorflow==2.4.0)
#   Using cached Werkzeug-2.2.3-py3-none-any.whl.metadata (4.4 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0)
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0) (0.2.2)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow==2.4.0)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.0) (4.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0) (2018.8.24)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard~=2.4->tensorflow==2.4.0)
#   Using cached MarkupSafe-2.1.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: zipp>=0.5 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.0) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.1 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0) (0.4.4)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow==2.4.0)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Downloading tensorflow-2.4.0-cp37-cp37m-manylinux2010_x86_64.whl (394.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.7/394.7 MB 4.6 MB/s eta 0:00:00m eta 0:00:010:00:02
# Using cached gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Downloading absl_py-0.15.0-py3-none-any.whl (132 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 kB 12.6 MB/s eta 0:00:00
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading grpcio-1.32.0-cp37-cp37m-manylinux2014_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 3.8 MB/s eta 0:00:00m eta 0:00:010:01:01
# Using cached h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
# Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Downloading numpy-1.19.5-cp37-cp37m-manylinux2010_x86_64.whl (14.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 5.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Using cached tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
# Downloading protobuf-3.20.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 5.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading tensorflow_estimator-2.4.0-py2.py3-none-any.whl (462 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.0/462.0 kB 5.4 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Using cached wheel-0.42.0-py3-none-any.whl (65 kB)
# Using cached google_auth-2.38.0-py2.py3-none-any.whl (210 kB)
# Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Using cached Markdown-3.4.4-py3-none-any.whl (94 kB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached setuptools-68.0.0-py3-none-any.whl (804 kB)
# Using cached tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
# Using cached Werkzeug-2.2.3-py3-none-any.whl (233 kB)
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Using cached MarkupSafe-2.1.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Building wheels for collected packages: termcolor, wrapt
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4001 sha256=955cba37c6e84cffeaf7c0eb5d538f36ba2467f9f0de0b5e520dd6192d892f44
#   Stored in directory: /home/pasiya/.cache/pip/wheels/3f/e3/ec/8a8336ff196023622fbcb36de0c5a5c218cbb24111d1d4c7f2
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp37-cp37m-linux_x86_64.whl size=69661 sha256=ff89fc6a61352ebf0b7917a6863a4fe4138bfcd0f81becc761bebcdcbe7c4a2a
#   Stored in directory: /home/pasiya/.cache/pip/wheels/62/76/4c/aa25851149f3f6d9785f6c869387ad82b3fd37582fa8147ac6
# Successfully built termcolor wrapt
# Installing collected packages: wrapt, typing-extensions, termcolor, tensorflow-estimator, flatbuffers, wheel, tensorboard-data-server, six, setuptools, rsa, requests, protobuf, oauthlib, numpy, MarkupSafe, gast, cachetools, werkzeug, requests-oauthlib, opt-einsum, markdown, keras-preprocessing, h5py, grpcio, google-pasta, google-auth, astunparse, absl-py, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.10.11
# ERROR: Cannot uninstall 'wrapt'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.

# %%
import tensorflow as tf
import shap

print(tf.__version__)
print(shap.__version__)

print(X_train.shape)  # Should be (num_samples, time_step, num_features)
print(X_test.shape)   # Should be (num_samples, time_step, num_features)
# Out:
# 2.18.0
# 0.46.0
# (8, 12, 1)
# (3, 12, 1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import shap

data = pd.read_csv('2023-2024-Horana-cleaned.csv')
data['DATE'] = pd.to_datetime(data['DATE'])
data['NetAmount'] = data['NetAmount'].abs()  # Ensure all values are positive

sales_265 = data[data['SalesPersonCode'] == '0']

sales_265_monthly = sales_265.resample('M', on='DATE')['NetAmount'].sum().reset_index()
sales_265_monthly.set_index('DATE', inplace=True)

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_sales = scaler.fit_transform(sales_265_monthly[['NetAmount']])

def create_dataset(data, time_step=12):
    X, y = [], []
    for i in range(len(data) - time_step):
        X.append(data[i:i + time_step, 0])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)

time_step = 12  
X, y = create_dataset(scaled_sales, time_step)

if len(X) == 0 or len(y) == 0:
    raise ValueError("Not enough data to create sequences. Reduce time_step or use a larger dataset.")

X = X.reshape(X.shape[0], X.shape[1], 1)

train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

if len(X_train) == 0 or len(X_test) == 0:
    raise ValueError("Not enough data to split into train and test sets. Reduce time_step or use a larger dataset.")

print(f"X shape: {X.shape}")
print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")

model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(time_step, 1)),
    LSTM(50, return_sequences=False),
    Dense(1)
])

model.compile(optimizer='adam', loss='mean_squared_error')

model.fit(X_train, y_train, epochs=50, batch_size=8, verbose=1)

last_12_months = scaled_sales[-time_step:].reshape(1, time_step, 1)
predicted_scaled = model.predict(last_12_months)

predicted_sales = scaler.inverse_transform([[predicted_scaled[0][0]]])[0][0]

actual_sales = sales_265_monthly['NetAmount'].iloc[-1]

print(f"Actual Sales for Last Month: {actual_sales:.2f}")
print(f"Predicted Sales for Last Month: {predicted_sales:.2f}")

plt.figure(figsize=(10, 5))
plt.plot(sales_265_monthly.index[-12:], sales_265_monthly['NetAmount'][-12:], label="Actual", marker='o')
plt.axhline(y=predicted_sales, color='r', linestyle='--', label="Predicted Last Month")
plt.legend()
plt.title("Actual vs Predicted Monthly Sales for SalesPerson 254")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.grid()
plt.show()

background_data = X_train[:100]  # Use the first 100 samples as background data
test_data = X_train[100:150]     # Use the next 50 samples for explanation

if len(test_data) == 0:
    raise ValueError("test_data is empty. Check the data splitting process.")

explainer = shap.GradientExplainer(model, background_data)

shap_values = explainer.shap_values(test_data)

shap.initjs()

shap.summary_plot(shap_values, test_data, feature_names=["Sales"], plot_type="bar")

sample_index = 0  
shap.force_plot(explainer.expected_value[0], shap_values[0][sample_index], test_data[sample_index], feature_names=["Sales"])
# Out:
# X shape: (12, 12, 1)
# X_train shape: (9, 12, 1)
# X_test shape: (3, 12, 1)
# Epoch 1/50
# /tmp/ipykernel_33307/242669497.py:18: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   sales_265_monthly = sales_265.resample('M', on='DATE')['NetAmount'].sum().reset_index()
# /home/pasiya/sales_forcast/jupytercode/lstm/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[7], line 69
#      66 model.compile(optimizer='adam', loss='mean_squared_error')
#      68 # Train the model
# ---> 69 model.fit(X_train, y_train, epochs=50, batch_size=8, verbose=1)
#      71 # Predict next month's value
#      72 last_12_months = scaled_sales[-time_step:].reshape(1, time_step, 1)
#
# File ~/sales_forcast/jupytercode/lstm/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/sales_forcast/jupytercode/lstm/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:77, in TensorFlowTrainer.train_step(self, data)
#      75 if self.trainable_weights:
#      76     trainable_weights = self.trainable_weights
# ---> 77     gradients = tape.gradient(loss, trainable_weights)
#      79     # Update weights
#      80     self.optimizer.apply_gradients(zip(gradients, trainable_weights))
#
# LookupError: gradient registry has no entry for: shap_DivNoNan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import shap

data = pd.read_csv('2023-2024-Horana-cleaned.csv')
data['DATE'] = pd.to_datetime(data['DATE'])
data['NetAmount'] = data['NetAmount'].abs()  # Ensure all values are positive

sales_265 = data[data['SalesPersonCode'] == '265']

sales_265_monthly = sales_265.resample('M', on='DATE')['NetAmount'].sum().reset_index()
sales_265_monthly.set_index('DATE', inplace=True)

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_sales = scaler.fit_transform(sales_265_monthly[['NetAmount']])

def create_dataset(data, time_step=12):
    X, y = [], []
    for i in range(len(data) - time_step):
        X.append(data[i:i + time_step, 0])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)

time_step = 12  
X, y = create_dataset(scaled_sales, time_step)

X = X.reshape(X.shape[0], X.shape[1], 1)

train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

print(X_test[0:5])
print(y_test[0:5])

model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(time_step, 1)),
    LSTM(50, return_sequences=False),
    Dense(1)
])

model.compile(optimizer='adam', loss='mean_squared_error')

model.fit(X_train, y_train, epochs=50, batch_size=8, verbose=1)

last_12_months = scaled_sales[-time_step:].reshape(1, time_step, 1)
predicted_scaled = model.predict(last_12_months)

predicted_sales = scaler.inverse_transform([[predicted_scaled[0][0]]])[0][0]

actual_sales = sales_265_monthly['NetAmount'].iloc[-1]

print(f"Actual Sales for Last Month: {actual_sales:.2f}")
print(f"Predicted Sales for Last Month: {predicted_sales:.2f}")

plt.figure(figsize=(10, 5))
plt.plot(sales_265_monthly.index[-12:], sales_265_monthly['NetAmount'][-12:], label="Actual", marker='o')
plt.axhline(y=predicted_sales, color='r', linestyle='--', label="Predicted Last Month")
plt.legend()
plt.title("Actual vs Predicted Monthly Sales for SalesPerson 265")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.grid()
plt.show()

try:
    background_samples_count = min(50, X_train.shape[0])  # Take 50 samples, or all if less than 50
    
    background_samples = X_train[np.random.choice(X_train.shape[0], background_samples_count, replace=False)]
    
    explainer = shap.KernelExplainer(model.predict, background_samples)
    
    X_test_2d = X_test.reshape(X_test.shape[0], -1)
    
    shap_values = explainer.shap_values(X_test_2d[:10])  # Use a small test set
    
    print("\n==== SHAP Debugging Info ====")
    print("SHAP Values Type:", type(shap_values))
    print("SHAP Values Shape:", np.array(shap_values).shape)
    print("X_test Shape:", X_test.shape)
    
    shap.initjs()
    shap.force_plot(explainer.expected_value[0], shap_values[0], X_test_2d[0], feature_names=[f"Month {i+1}" for i in range(time_step)])


except Exception as e:
    print(f"Error with SHAP: {e}")
# Out:
# [[[0.37299027]
#   [0.32504311]
#   [0.84524082]
#   [0.4380347 ]
#   [0.1994462 ]
#   [0.40915856]
#   [0.63738907]
#   [0.32098713]
#   [0.39686476]
#   [0.5424924 ]
#   [0.57958473]
#   [0.47801379]]
#
#  [[0.32504311]
#   [0.84524082]
#   [0.4380347 ]
#   [0.1994462 ]
#   [0.40915856]
#   [0.63738907]
#   [0.32098713]
#   [0.39686476]
#   [0.5424924 ]
#   [0.57958473]
#   [0.47801379]
#   [0.3257526 ]]
#
#  [[0.84524082]
#   [0.4380347 ]
#   [0.1994462 ]
#   [0.40915856]
#   [0.63738907]
#   [0.32098713]
#   [0.39686476]
#   [0.5424924 ]
#   [0.57958473]
#   [0.47801379]
#   [0.3257526 ]
#   [0.40509156]]]
# [0.3257526  0.40509156 1.        ]
# Epoch 1/50
# /tmp/ipykernel_11781/3569754406.py:18: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   sales_265_monthly = sales_265.resample('M', on='DATE')['NetAmount'].sum().reset_index()
# /home/pasiya/sales_forcast/jupytercode/lstm/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.2012
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1269
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0809
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0353
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0162
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0195
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0355
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0334
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0237
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0163
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0148
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0153
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0176
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0184
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0192
# Epoch 16/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0165
# Epoch 17/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0133
# Epoch 18/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0144
# Epoch 19/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0167
# Epoch 20/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0202
# Epoch 21/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0219
# Epoch 22/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0204
# Epoch 23/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0187
# Epoch 24/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0165
# Epoch 25/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0146
# Epoch 26/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0155
# Epoch 27/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0129
# Epoch 28/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0151
# Epoch 29/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0149
# Epoch 30/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0154
# Epoch 31/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0164
# Epoch 32/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0155
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0158
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0151
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0129
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0147
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0148
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0144
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0149
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0150
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0146
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0151
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0149
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0148
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0126
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0147
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0153
# Epoch 48/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0159
# Epoch 49/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0161
# Epoch 50/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0163
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e3a2d112c20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# Actual Sales for Last Month: 3760003.98
# Predicted Sales for Last Month: 1833974.24
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e3a2d112c20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
#   0%|          | 0/3 [00:00<?, ?it/s]
# Error with SHAP: Exception encountered when calling Sequential.call().
#
# Cannot take the length of shape with unknown rank.
#
# Arguments received by Sequential.call():
#   • inputs=tf.Tensor(shape=<unknown>, dtype=float32)
#   • training=False
#   • mask=None

# %%
# !pip install optuna
import shap
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import optuna
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

data = pd.read_csv('2023-2024-Horana-cleaned.csv')
data['DATE'] = pd.to_datetime(data['DATE'])
data['NetAmount'] = data['NetAmount'].abs()

sales_265 = data[data['SalesPersonCode'] == '265']

sales_265_monthly = sales_265.resample('ME', on='DATE')['NetAmount'].sum().reset_index()
sales_265_monthly.set_index('DATE', inplace=True)

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_sales = scaler.fit_transform(sales_265_monthly[['NetAmount']])

def create_dataset(data, time_step=12):
    X, y = [], []
    for i in range(len(data) - time_step):
        X.append(data[i:i + time_step, 0])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)

time_step = 12  # 12 months for yearly trends
X, y = create_dataset(scaled_sales, time_step)
X = X.reshape(X.shape[0], X.shape[1], 1)

train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

def objective(trial):
    """Objective function for Optuna hyperparameter tuning."""
    # Hyperparameter search space
    n_layers = trial.suggest_int('n_layers', 1, 2)
    n_units = trial.suggest_int('n_units', 20, 100, step=10)
    dropout_rate = trial.suggest_float('dropout_rate', 0.1, 0.5)
    learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    batch_size = trial.suggest_categorical('batch_size', [8, 16, 32])
    
    model = Sequential()
    model.add(LSTM(n_units, return_sequences=(n_layers == 2), input_shape=(time_step, 1)))
    model.add(Dropout(dropout_rate))
    
    if n_layers == 2:
        model.add(LSTM(n_units))
        model.add(Dropout(dropout_rate))
    
    model.add(Dense(1))
    
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mean_squared_error')
    
    early_stopping = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)
    model.fit(X_train, y_train, epochs=50, batch_size=batch_size, verbose=0, callbacks=[early_stopping])
    
    loss = model.evaluate(X_test, y_test, verbose=0)
    return loss

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=20)

best_params = study.best_params
print("Best hyperparameters:", best_params)

final_model = Sequential()
final_model.add(LSTM(best_params['n_units'], return_sequences=(best_params['n_layers'] == 2), input_shape=(time_step, 1)))
final_model.add(Dropout(best_params['dropout_rate']))

if best_params['n_layers'] == 2:
    final_model.add(LSTM(best_params['n_units']))
    final_model.add(Dropout(best_params['dropout_rate']))

final_model.add(Dense(1))
final_model.compile(optimizer=Adam(learning_rate=best_params['learning_rate']), loss='mean_squared_error')

final_model.fit(X_train, y_train, epochs=50, batch_size=best_params['batch_size'], verbose=1, callbacks=[EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)])

last_12_months = scaled_sales[-time_step:].reshape(1, time_step, 1)
predicted_scaled = final_model.predict(last_12_months)
predicted_sales = scaler.inverse_transform([[predicted_scaled[0][0]]])[0][0]

actual_sales = sales_265_monthly['NetAmount'].iloc[-1]

print(f"Actual Sales for Last Month: {actual_sales:.2f}")
print(f"Predicted Sales for Last Month: {predicted_sales:.2f}")

plt.figure(figsize=(10, 5))
plt.plot(sales_265_monthly.index[-12:], sales_265_monthly['NetAmount'][-12:], label="Actual", marker='o')
plt.axhline(y=predicted_sales, color='r', linestyle='--', label="Predicted Last Month")
plt.legend()
plt.title("Actual vs Predicted Monthly Sales for SalesPerson 265")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.grid()
plt.show()


try:
    background_samples = X_train[np.random.choice(X_train.shape[0], min(50, X_train.shape[0]), replace=False)]

    explainer = shap.GradientExplainer(final_model, background_samples)

    X_test_shap = X_test[:3]  
    print(f'>>>>>>>>>>:{X_test_shap}')

    shap_values = explainer.shap_values(X_test_shap)

    shap_values_reshaped = np.array(shap_values).reshape(3, 12)  

    influential_reasons = []

    for i in range(shap_values_reshaped.shape[0]):  
        # print(f"\n==== top 3 influential reasons for prediction (sample {i+1}) ====")

        top_indices = np.argsort(np.abs(shap_values_reshaped[i]))[-3:][::-1]  

        for rank, j in enumerate(top_indices, 1):  
            contribution = shap_values_reshaped[i, j]
            direction = "increased" if contribution > 0 else "decreased"
            # message = f"month {j+1} {direction} prediction by {abs(contribution):.4f}"
            # print(f"top {rank}: {message}")

            influential_reasons.append((j+1, contribution))

    top_overall = sorted(influential_reasons, key=lambda x: abs(x[1]), reverse=True)[:3]

    print("\n==== highest 3 influential reasons overall ====")
    for rank, (month, value) in enumerate(top_overall, 1):
        direction = "increased" if value > 0 else "decreased"
        print(f"top {rank}: month {month} {direction} prediction by {abs(value):.4f}")

except Exception as e:
    print(f"error with shap: {e}")
# Out:
# [I 2025-03-12 16:07:14,948] A new study created in memory with name: no-name-7c1b7ff5-10d7-4caf-9a5e-0254a6680b90
# /home/pasiya/sales_forcast/jupytercode/tf/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# [I 2025-03-12 16:07:18,860] Trial 0 finished with value: 0.08752108365297318 and parameters: {'n_layers': 2, 'n_units': 60, 'dropout_rate': 0.11085403860156746, 'learning_rate': 0.00023435834775266165, 'batch_size': 8}. Best is trial 0 with value: 0.08752108365297318.
# [I 2025-03-12 16:07:24,146] Trial 1 finished with value: 0.09886180609464645 and parameters: {'n_layers': 2, 'n_units': 30, 'dropout_rate': 0.1342892198105503, 'learning_rate': 0.0001370440102880683, 'batch_size': 8}. Best is trial 0 with value: 0.08752108365297318.
# [I 2025-03-12 16:07:27,228] Trial 2 finished with value: 0.10176482796669006 and parameters: {'n_layers': 1, 'n_units': 60, 'dropout_rate': 0.4118131285655352, 'learning_rate': 0.004413865556968158, 'batch_size': 8}. Best is trial 0 with value: 0.08752108365297318.
# [I 2025-03-12 16:07:28,963] Trial 3 finished with value: 0.1263485699892044 and parameters: {'n_layers': 1, 'n_units': 30, 'dropout_rate': 0.45390423747065156, 'learning_rate': 0.0019236237191175458, 'batch_size': 32}. Best is trial 0 with value: 0.08752108365297318.
# [I 2025-03-12 16:07:30,525] Trial 4 finished with value: 0.12673714756965637 and parameters: {'n_layers': 1, 'n_units': 60, 'dropout_rate': 0.31453168225660094, 'learning_rate': 0.005798353226680708, 'batch_size': 16}. Best is trial 0 with value: 0.08752108365297318.
# [I 2025-03-12 16:07:33,755] Trial 5 finished with value: 0.09160291403532028 and parameters: {'n_layers': 1, 'n_units': 90, 'dropout_rate': 0.29565234666621204, 'learning_rate': 0.00029337761164311766, 'batch_size': 32}. Best is trial 0 with value: 0.08752108365297318.
# [I 2025-03-12 16:07:37,587] Trial 6 finished with value: 0.08934104442596436 and parameters: {'n_layers': 2, 'n_units': 60, 'dropout_rate': 0.4056372517488527, 'learning_rate': 0.00022179536327660736, 'batch_size': 8}. Best is trial 0 with value: 0.08752108365297318.

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /home/pasiya/anaconda3/lib/python3.7/site-packages (0.13.5)
# Requirement already satisfied: pandas>=0.25 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from statsmodels) (1.1.5)
# Requirement already satisfied: patsy>=0.5.2 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from statsmodels) (24.0)
# Requirement already satisfied: scipy>=1.3 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from statsmodels) (1.7.3)
# Requirement already satisfied: numpy>=1.17 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from statsmodels) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from pandas>=0.25->statsmodels) (2.7.3)
# Requirement already satisfied: pytz>=2017.2 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from pandas>=0.25->statsmodels) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/pasiya/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=0.25->statsmodels) (1.16.0)

# %%
import shap
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import optuna
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

data = pd.read_csv('2023-2024-Horana-cleaned.csv')
data['DATE'] = pd.to_datetime(data['DATE'])
data['NetAmount'] = data['NetAmount'].abs()

sales_265 = data[data['SalesPersonCode'] == '265']

sales_265_monthly = sales_265.resample('ME', on='DATE')['NetAmount'].sum().reset_index()
sales_265_monthly.set_index('DATE', inplace=True)

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_sales = scaler.fit_transform(sales_265_monthly[['NetAmount']])

def create_dataset(data, time_step=12):
    X, y = [], []
    for i in range(len(data) - time_step):
        X.append(data[i:i + time_step, 0])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)

time_step = 12 
X, y = create_dataset(scaled_sales, time_step)
X = X.reshape(X.shape[0], X.shape[1], 1)

train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

def objective(trial):
    """Objective function for Optuna hyperparameter tuning."""
    # Hyperparameter search space
    n_layers = trial.suggest_int('n_layers', 1, 2)
    n_units = trial.suggest_int('n_units', 20, 100, step=10)
    dropout_rate = trial.suggest_float('dropout_rate', 0.1, 0.5)
    learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    batch_size = trial.suggest_categorical('batch_size', [8, 16, 32])
    
    model = Sequential()
    model.add(LSTM(n_units, return_sequences=(n_layers == 2), input_shape=(time_step, 1)))
    model.add(Dropout(dropout_rate))
    
    if n_layers == 2:
        model.add(LSTM(n_units))
        model.add(Dropout(dropout_rate))
    
    model.add(Dense(1))
    
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mean_squared_error')
    
    early_stopping = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)
    model.fit(X_train, y_train, epochs=50, batch_size=batch_size, verbose=0, callbacks=[early_stopping])
    
    loss = model.evaluate(X_test, y_test, verbose=0)
    return loss

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=20)

best_params = study.best_params
print("Best hyperparameters:", best_params)

final_model = Sequential()
final_model.add(LSTM(best_params['n_units'], return_sequences=(best_params['n_layers'] == 2), input_shape=(time_step, 1)))
final_model.add(Dropout(best_params['dropout_rate']))

if best_params['n_layers'] == 2:
    final_model.add(LSTM(best_params['n_units']))
    final_model.add(Dropout(best_params['dropout_rate']))

final_model.add(Dense(1))
final_model.compile(optimizer=Adam(learning_rate=best_params['learning_rate']), loss='mean_squared_error')

final_model.fit(X_train, y_train, epochs=50, batch_size=best_params['batch_size'], verbose=1, callbacks=[EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)])

last_12_months = scaled_sales[-time_step:].reshape(1, time_step, 1)
predicted_scaled = final_model.predict(last_12_months)
predicted_sales = scaler.inverse_transform([[predicted_scaled[0][0]]])[0][0]

next_month = sales_265_monthly.index[-1] + pd.DateOffset(months=1)

217print(f"predicted sales for {next_month.strftime('%b %Y')}: {predicted_sales:.2f}")

# plot results
plt.figure(figsize=(10, 5))
plt.plot(sales_265_monthly.index[-12:], sales_265_monthly['NetAmount'][-12:], label="actual", marker='o')
plt.scatter(next_month, predicted_sales, color='red', marker='x', label="predicted next month")
plt.legend()
plt.title("actual vs predicted monthly sales for salesperson 265")
plt.xlabel("date")
plt.ylabel("sales")
plt.xticks(rotation=45)
plt.grid()
plt.show()



try:
    background_samples = X_train[np.random.choice(X_train.shape[0], min(50, X_train.shape[0]), replace=False)]

    explainer = shap.GradientExplainer(final_model, background_samples)

    X_test_shap = X_test[:3]  
    # print(f'>>>>>>>>>>:{X_test_shap}')

    shap_values = explainer.shap_values(X_test_shap)

    shap_values_reshaped = np.array(shap_values).reshape(3, 12)  

    influential_reasons = []

    for i in range(shap_values_reshaped.shape[0]):  

        top_indices = np.argsort(np.abs(shap_values_reshaped[i]))[-3:][::-1]  

        for rank, j in enumerate(top_indices, 1):  
            contribution = shap_values_reshaped[i, j]
            direction = "increased" if contribution > 0 else "decreased"

            influential_reasons.append((j+1, contribution))

    top_overall = sorted(influential_reasons, key=lambda x: abs(x[1]), reverse=True)[:3]

    print("\n==== highest 3 influential reasons overall ====")
    for rank, (month, value) in enumerate(top_overall, 1):
        direction = "increased" if value > 0 else "decreased"
        print(f"top {rank}: month {month} {direction} prediction by {abs(value):.4f}")

except Exception as e:
    print(f"error with shap: {e}")
# Out:
# 2025-03-12 22:47:09.156998: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-12 22:47:09.313621: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-12 22:47:09.383788: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-12 22:47:09.384250: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-12 22:47:09.500258: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-12 22:47:10.156396: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [I 2025-03-12 22:47:10,667] A new study created in memory with name: no-name-9268e6ba-7773-4da8-ad26-df6c2b5c17c8
# 2025-03-12 22:47:10.691757: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:282] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# /home/pasiya/sales_forcast/jupytercode/tf/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# [I 2025-03-12 22:47:12,413] Trial 0 finished with value: 0.09011828154325485 and parameters: {'n_layers': 1, 'n_units': 90, 'dropout_rate': 0.29096610736269507, 'learning_rate': 0.0002790156793436292, 'batch_size': 8}. Best is trial 0 with value: 0.09011828154325485.
# [I 2025-03-12 22:47:14,167] Trial 1 finished with value: 0.12501364946365356 and parameters: {'n_layers': 2, 'n_units': 30, 'dropout_rate': 0.36357588963790055, 'learning_rate': 0.005097554533377607, 'batch_size': 32}. Best is trial 0 with value: 0.09011828154325485.
# [I 2025-03-12 22:47:15,579] Trial 2 finished with value: 0.09512390941381454 and parameters: {'n_layers': 1, 'n_units': 70, 'dropout_rate': 0.1333077667719536, 'learning_rate': 0.0005396655475535103, 'batch_size': 16}. Best is trial 0 with value: 0.09011828154325485.
# [I 2025-03-12 22:47:17,263] Trial 3 finished with value: 0.16252191364765167 and parameters: {'n_layers': 2, 'n_units': 40, 'dropout_rate': 0.1698992033975747, 'learning_rate': 0.006564321256238135, 'batch_size': 32}. Best is trial 0 with value: 0.09011828154325485.
# [I 2025-03-12 22:47:18,231] Trial 4 finished with value: 0.5260208249092102 and parameters: {'n_layers': 1, 'n_units': 30, 'dropout_rate': 0.16340879922537557, 'learning_rate': 0.00014718528122913523, 'batch_size': 32}. Best is trial 0 with value: 0.09011828154325485.
# [I 2025-03-12 22:47:19,308] Trial 5 finished with value: 0.09522241353988647 and parameters: {'n_layers': 1, 'n_units': 70, 'dropout_rate': 0.34195835729991814, 'learning_rate': 0.004888296442665196, 'batch_size': 8}. Best is trial 0 with value: 0.09011828154325485.
# [I 2025-03-12 22:47:20,912] Trial 6 finished with value: 0.1005597934126854 and parameters: {'n_layers': 1, 'n_units': 70, 'dropout_rate': 0.2086977670104595, 'learning_rate': 0.00023777386754053633, 'batch_size': 8}. Best is trial 0 with value: 0.09011828154325485.
# [I 2025-03-12 22:47:22,071] Trial 7 finished with value: 0.09484606981277466 and parameters: {'n_layers': 1, 'n_units': 40, 'dropout_rate': 0.12200027007748125, 'learning_rate': 0.001347701731299969, 'batch_size': 16}. Best is trial 0 with value: 0.09011828154325485.
# [I 2025-03-12 22:47:23,833] Trial 8 finished with value: 0.09089051932096481 and parameters: {'n_layers': 2, 'n_units': 80, 'dropout_rate': 0.2789394987221824, 'learning_rate': 0.0028120569519217713, 'batch_size': 8}. Best is trial 0 with value: 0.09011828154325485.
# [I 2025-03-12 22:47:25,953] Trial 9 finished with value: 0.12036537379026413 and parameters: {'n_layers': 2, 'n_units': 20, 'dropout_rate': 0.2815499346057324, 'learning_rate': 0.000906763620902145, 'batch_size': 16}. Best is trial 0 with value: 0.09011828154325485.
# [I 2025-03-12 22:47:27,605] Trial 10 finished with value: 0.09682977199554443 and parameters: {'n_layers': 1, 'n_units': 100, 'dropout_rate': 0.49172717167900465, 'learning_rate': 0.0003543717810684446, 'batch_size': 8}. Best is trial 0 with value: 0.09011828154325485.
# [I 2025-03-12 22:47:29,540] Trial 11 finished with value: 0.097504623234272 and parameters: {'n_layers': 2, 'n_units': 100, 'dropout_rate': 0.2683917634208056, 'learning_rate': 0.0022461243347836166, 'batch_size': 8}. Best is trial 0 with value: 0.09011828154325485.
# [I 2025-03-12 22:47:32,144] Trial 12 finished with value: 0.09401348233222961 and parameters: {'n_layers': 2, 'n_units': 90, 'dropout_rate': 0.4067352350084431, 'learning_rate': 0.0001105846680924714, 'batch_size': 8}. Best is trial 0 with value: 0.09011828154325485.
# [I 2025-03-12 22:47:34,428] Trial 13 finished with value: 0.12105878442525864 and parameters: {'n_layers': 2, 'n_units': 80, 'dropout_rate': 0.23495887803793725, 'learning_rate': 0.0023327435733968786, 'batch_size': 8}. Best is trial 0 with value: 0.09011828154325485.
# [I 2025-03-12 22:47:35,567] Trial 14 finished with value: 0.08844677358865738 and parameters: {'n_layers': 1, 'n_units': 90, 'dropout_rate': 0.3316672552837191, 'learning_rate': 0.000637600578011122, 'batch_size': 8}. Best is trial 14 with value: 0.08844677358865738.
# [I 2025-03-12 22:47:36,726] Trial 15 finished with value: 0.10091974586248398 and parameters: {'n_layers': 1, 'n_units': 90, 'dropout_rate': 0.41736917067490836, 'learning_rate': 0.0006064834149027651, 'batch_size': 8}. Best is trial 14 with value: 0.08844677358865738.
# [I 2025-03-12 22:47:38,484] Trial 16 finished with value: 0.09413627535104752 and parameters: {'n_layers': 1, 'n_units': 60, 'dropout_rate': 0.34221074667296997, 'learning_rate': 0.00024440110435298924, 'batch_size': 8}. Best is trial 14 with value: 0.08844677358865738.
# [I 2025-03-12 22:47:40,018] Trial 17 finished with value: 0.09669297933578491 and parameters: {'n_layers': 1, 'n_units': 60, 'dropout_rate': 0.4051487668460877, 'learning_rate': 0.00045136804577967167, 'batch_size': 8}. Best is trial 14 with value: 0.08844677358865738.
# [I 2025-03-12 22:47:41,242] Trial 18 finished with value: 0.08957704901695251 and parameters: {'n_layers': 1, 'n_units': 90, 'dropout_rate': 0.31765536171109804, 'learning_rate': 0.0011282988931916773, 'batch_size': 16}. Best is trial 14 with value: 0.08844677358865738.
# [I 2025-03-12 22:47:42,401] Trial 19 finished with value: 0.09410551935434341 and parameters: {'n_layers': 1, 'n_units': 100, 'dropout_rate': 0.4529293003540322, 'learning_rate': 0.0009692682085824726, 'batch_size': 16}. Best is trial 14 with value: 0.08844677358865738.
# Best hyperparameters: {'n_layers': 1, 'n_units': 90, 'dropout_rate': 0.3316672552837191, 'learning_rate': 0.000637600578011122, 'batch_size': 8}
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2342
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2106
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1506
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1226
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0897
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0753
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0454
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0338
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0239
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0161
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0150
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0266
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0386
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0277
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0218
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# predicted sales for Jan 2025: 2156580.83
# >>>>>>>>>>:[[[0.37299027]
#   [0.32504311]
#   [0.84524082]
#   [0.4380347 ]
#   [0.1994462 ]
#   [0.40915856]
#   [0.63738907]
#   [0.32098713]
#   [0.39686476]
#   [0.5424924 ]
#   [0.57958473]
#   [0.47801379]]
#
#  [[0.32504311]
#   [0.84524082]
#   [0.4380347 ]
#   [0.1994462 ]
#   [0.40915856]
#   [0.63738907]
#   [0.32098713]
#   [0.39686476]
#   [0.5424924 ]
#   [0.57958473]
#   [0.47801379]
#   [0.3257526 ]]
#
#  [[0.84524082]
#   [0.4380347 ]
#   [0.1994462 ]
#   [0.40915856]
#   [0.63738907]
#   [0.32098713]
#   [0.39686476]
#   [0.5424924 ]
#   [0.57958473]
#   [0.47801379]
#   [0.3257526 ]
#   [0.40509156]]]
# /home/pasiya/sales_forcast/jupytercode/tf/lib/python3.10/site-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_203
# Received: inputs=['Tensor(shape=(3, 12, 1))']
#   warnings.warn(msg)
# /home/pasiya/sales_forcast/jupytercode/tf/lib/python3.10/site-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_203
# Received: inputs=['Tensor(shape=(50, 12, 1))']
#   warnings.warn(msg)
# ==== highest 3 influential reasons overall ====
# top 1: month 3 increased prediction by 0.0443
# top 2: month 2 increased prediction by 0.0366
# top 3: month 5 increased prediction by 0.0321

# %%
import shap
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import optuna
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

data = pd.read_csv('2023-2024-Horana-cleaned.csv')
data['DATE'] = pd.to_datetime(data['DATE'])
data['NetAmount'] = data['NetAmount'].abs()

kpi_data = pd.read_csv('KPI.csv')
kpi_data['Year-Month'] = pd.to_datetime(kpi_data['Year-Month'], format='%Y-%m')
kpi_data['Person Code'] = kpi_data['Person Code'].astype(str)

sales_265 = data[data['SalesPersonCode'] == '265']
sales_265_monthly = sales_265.resample('ME', on='DATE')['NetAmount'].sum().reset_index()
sales_265_monthly['Year-Month'] = sales_265_monthly['DATE'].dt.to_period('M').dt.to_timestamp()

merged_data = sales_265_monthly.merge(kpi_data, on=['Year-Month'], how='left')

features = ['NetAmount', 'Punctuality', 'Absenteeism', 'Maintaining Env', 'Sales Perf', 'Cust. Sat']
merged_data[features] = merged_data[features].apply(pd.to_numeric)

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(merged_data[features])

def create_dataset(data, time_step=12):
    X, y = [], []
    for i in range(len(data) - time_step):
        X.append(data[i:i + time_step])
        y.append(data[i + time_step, 0])  # NetAmount as target
    return np.array(X), np.array(y)

time_step = 12
X, y = create_dataset(scaled_data, time_step)
X = X.reshape(X.shape[0], X.shape[1], X.shape[2])

train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

def objective(trial):
    n_layers = trial.suggest_int('n_layers', 1, 2)
    n_units = trial.suggest_int('n_units', 20, 100, step=10)
    dropout_rate = trial.suggest_float('dropout_rate', 0.1, 0.5)
    learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    batch_size = trial.suggest_categorical('batch_size', [8, 16, 32])
    
    model = Sequential()
    model.add(LSTM(n_units, return_sequences=(n_layers == 2), input_shape=(time_step, X.shape[2])))
    model.add(Dropout(dropout_rate))
    
    if n_layers == 2:
        model.add(LSTM(n_units))
        model.add(Dropout(dropout_rate))
    
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mean_squared_error')
    
    early_stopping = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)
    model.fit(X_train, y_train, epochs=50, batch_size=batch_size, verbose=0, callbacks=[early_stopping])
    
    loss = model.evaluate(X_test, y_test, verbose=0)
    return loss

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=20)

best_params = study.best_params
print("Best hyperparameters:", best_params)

final_model = Sequential()
final_model.add(LSTM(best_params['n_units'], return_sequences=(best_params['n_layers'] == 2), input_shape=(time_step, X.shape[2])))
final_model.add(Dropout(best_params['dropout_rate']))

if best_params['n_layers'] == 2:
    final_model.add(LSTM(best_params['n_units']))
    final_model.add(Dropout(best_params['dropout_rate']))

final_model.add(Dense(1))
final_model.compile(optimizer=Adam(learning_rate=best_params['learning_rate']), loss='mean_squared_error')

final_model.fit(X_train, y_train, epochs=50, batch_size=best_params['batch_size'], verbose=1, callbacks=[EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)])

last_12_months = scaled_data[-time_step:].reshape(1, time_step, scaled_data.shape[1])
predicted_scaled = final_model.predict(last_12_months)
predicted_sales = scaler.inverse_transform([[predicted_scaled[0][0]] + [0] * (scaled_data.shape[1] - 1)])[0][0]

next_month = merged_data['Year-Month'].iloc[-1] + pd.DateOffset(months=1)
print(f"Predicted sales for {next_month.strftime('%b %Y')}: {predicted_sales:.2f}")

try:
    background_samples = X_train[np.random.choice(X_train.shape[0], min(50, X_train.shape[0]), replace=False)]
    explainer = shap.GradientExplainer(final_model, background_samples)
    X_test_shap = X_test[:3]
    shap_values = explainer.shap_values(X_test_shap)
    shap_values_reshaped = np.array(shap_values).reshape(3, time_step, X.shape[2])
    influential_reasons = {}
    for i in range(shap_values_reshaped.shape[0]):
        for j in range(1, X.shape[2]):  # Skip NetAmount
            month_index = np.argmax(np.abs(shap_values_reshaped[i, :, j]))
            month = merged_data['Year-Month'].iloc[train_size + month_index]
            key = (month, features[j])
            if key not in influential_reasons or abs(shap_values_reshaped[i, month_index, j]) > abs(influential_reasons[key]):
                influential_reasons[key] = shap_values_reshaped[i, month_index, j]
    top_overall = sorted(influential_reasons.items(), key=lambda x: abs(x[1]), reverse=True)[:3]
    print("\n==== Highest 3 Influential KPI Reasons Overall ====")
    for rank, ((month, kpi), value) in enumerate(top_overall, 1):
        direction = "increased" if value > 0 else "decreased"
        print(f"Top {rank}: ({month.strftime('%Y-%m')}) {kpi} {direction} prediction by {abs(value):.4f}")
except Exception as e:
    print(f"Error with SHAP: {e}")
# Out:
# [I 2025-03-16 21:01:18,359] A new study created in memory with name: no-name-46b3270a-0638-4ae3-a2f4-dc961b2899a1
# /home/pasiya/sales_forcast/jupytercode/tf/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# [I 2025-03-16 21:01:21,591] Trial 0 finished with value: 0.060946229845285416 and parameters: {'n_layers': 1, 'n_units': 100, 'dropout_rate': 0.26100037305607526, 'learning_rate': 0.0009475968922560385, 'batch_size': 32}. Best is trial 0 with value: 0.060946229845285416.
# [I 2025-03-16 21:01:25,246] Trial 1 finished with value: 0.0926041528582573 and parameters: {'n_layers': 2, 'n_units': 30, 'dropout_rate': 0.340794531898822, 'learning_rate': 0.001086741186435896, 'batch_size': 32}. Best is trial 0 with value: 0.060946229845285416.
# [I 2025-03-16 21:01:28,480] Trial 2 finished with value: 0.08549892902374268 and parameters: {'n_layers': 2, 'n_units': 30, 'dropout_rate': 0.25792312289483965, 'learning_rate': 0.0012030363836463213, 'batch_size': 16}. Best is trial 0 with value: 0.060946229845285416.
# [I 2025-03-16 21:01:35,482] Trial 3 finished with value: 0.026369480416178703 and parameters: {'n_layers': 2, 'n_units': 30, 'dropout_rate': 0.3621760804644608, 'learning_rate': 0.005640557996305551, 'batch_size': 8}. Best is trial 3 with value: 0.026369480416178703.
# [I 2025-03-16 21:01:38,419] Trial 4 finished with value: 0.10356210917234421 and parameters: {'n_layers': 1, 'n_units': 30, 'dropout_rate': 0.4955684049285133, 'learning_rate': 0.0001983473914840346, 'batch_size': 8}. Best is trial 3 with value: 0.026369480416178703.
# [I 2025-03-16 21:01:40,650] Trial 5 finished with value: 0.10383465141057968 and parameters: {'n_layers': 1, 'n_units': 40, 'dropout_rate': 0.49408040202266745, 'learning_rate': 0.00010265873553937213, 'batch_size': 8}. Best is trial 3 with value: 0.026369480416178703.
# [I 2025-03-16 21:01:43,590] Trial 6 finished with value: 0.028875399380922318 and parameters: {'n_layers': 1, 'n_units': 50, 'dropout_rate': 0.1330884922512624, 'learning_rate': 0.0037710696382853583, 'batch_size': 16}. Best is trial 3 with value: 0.026369480416178703.
# [I 2025-03-16 21:01:49,599] Trial 7 finished with value: 0.03445446863770485 and parameters: {'n_layers': 2, 'n_units': 60, 'dropout_rate': 0.4948450056392165, 'learning_rate': 0.004420707794912838, 'batch_size': 16}. Best is trial 3 with value: 0.026369480416178703.
# [I 2025-03-16 21:01:51,947] Trial 8 finished with value: 0.08164017647504807 and parameters: {'n_layers': 1, 'n_units': 90, 'dropout_rate': 0.165143739354096, 'learning_rate': 0.00015712347526529864, 'batch_size': 32}. Best is trial 3 with value: 0.026369480416178703.
# [I 2025-03-16 21:01:58,655] Trial 9 finished with value: 0.08531177788972855 and parameters: {'n_layers': 2, 'n_units': 90, 'dropout_rate': 0.2114873776847714, 'learning_rate': 0.0002741314864719483, 'batch_size': 16}. Best is trial 3 with value: 0.026369480416178703.
# [I 2025-03-16 21:02:06,089] Trial 10 finished with value: 0.024015337228775024 and parameters: {'n_layers': 2, 'n_units': 20, 'dropout_rate': 0.3823244468981511, 'learning_rate': 0.008697095103616364, 'batch_size': 8}. Best is trial 10 with value: 0.024015337228775024.
# [I 2025-03-16 21:02:12,912] Trial 11 finished with value: 0.02738919109106064 and parameters: {'n_layers': 2, 'n_units': 20, 'dropout_rate': 0.3867387956338595, 'learning_rate': 0.009604083855819956, 'batch_size': 8}. Best is trial 10 with value: 0.024015337228775024.
# [I 2025-03-16 21:02:19,199] Trial 12 finished with value: 0.024471573531627655 and parameters: {'n_layers': 2, 'n_units': 20, 'dropout_rate': 0.36962524104357525, 'learning_rate': 0.009789012376232817, 'batch_size': 8}. Best is trial 10 with value: 0.024015337228775024.
# [I 2025-03-16 21:02:25,797] Trial 13 finished with value: 0.03362464904785156 and parameters: {'n_layers': 2, 'n_units': 20, 'dropout_rate': 0.408680915435603, 'learning_rate': 0.00977054342284261, 'batch_size': 8}. Best is trial 10 with value: 0.024015337228775024.
# [I 2025-03-16 21:02:34,524] Trial 14 finished with value: 0.023760132491588593 and parameters: {'n_layers': 2, 'n_units': 50, 'dropout_rate': 0.4187427582187515, 'learning_rate': 0.0025474713373616472, 'batch_size': 8}. Best is trial 14 with value: 0.023760132491588593.
# [I 2025-03-16 21:02:42,305] Trial 15 finished with value: 0.031234009191393852 and parameters: {'n_layers': 2, 'n_units': 70, 'dropout_rate': 0.4329088698191139, 'learning_rate': 0.0022659751359805336, 'batch_size': 8}. Best is trial 14 with value: 0.023760132491588593.
# [I 2025-03-16 21:02:51,966] Trial 16 finished with value: 0.027028309181332588 and parameters: {'n_layers': 2, 'n_units': 70, 'dropout_rate': 0.30976869279913666, 'learning_rate': 0.002215676964773342, 'batch_size': 8}. Best is trial 14 with value: 0.023760132491588593.
# [I 2025-03-16 21:02:55,527] Trial 17 finished with value: 0.0777285173535347 and parameters: {'n_layers': 2, 'n_units': 50, 'dropout_rate': 0.448129805996334, 'learning_rate': 0.0005408119362094383, 'batch_size': 8}. Best is trial 14 with value: 0.023760132491588593.
# [I 2025-03-16 21:03:04,117] Trial 18 finished with value: 0.026721077039837837 and parameters: {'n_layers': 2, 'n_units': 50, 'dropout_rate': 0.3131849753757344, 'learning_rate': 0.0025828257913457077, 'batch_size': 8}. Best is trial 14 with value: 0.023760132491588593.
# [I 2025-03-16 21:03:06,882] Trial 19 finished with value: 0.10724310576915741 and parameters: {'n_layers': 2, 'n_units': 70, 'dropout_rate': 0.44476310795419444, 'learning_rate': 0.005905382963206005, 'batch_size': 32}. Best is trial 14 with value: 0.023760132491588593.
# Best hyperparameters: {'n_layers': 2, 'n_units': 50, 'dropout_rate': 0.4187427582187515, 'learning_rate': 0.0025474713373616472, 'batch_size': 8}
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1014
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0593
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0579
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0644
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0445
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0534
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0529
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0508
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0553
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0399
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0450
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0420
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0350
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0290
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0282
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0362
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0281
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0226
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0335
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0280
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0232
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0267
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0280
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0298
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0216
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0348
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# Predicted sales for Jan 2025: 3158660.90
# /home/pasiya/sales_forcast/jupytercode/tf/lib/python3.10/site-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_2042
# Received: inputs=['Tensor(shape=(3, 12, 6))']
#   warnings.warn(msg)
# /home/pasiya/sales_forcast/jupytercode/tf/lib/python3.10/site-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_2042
# Received: inputs=['Tensor(shape=(50, 12, 6))']
#   warnings.warn(msg)
# ==== Highest 3 Influential KPI Reasons Overall ====
# Top 1: (2024-08) Cust. Sat increased prediction by 0.0334
# Top 2: (2024-08) Absenteeism decreased prediction by 0.0328
# Top 3: (2024-07) Cust. Sat increased prediction by 0.0296
